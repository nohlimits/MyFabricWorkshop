# %%
###########################################################
##################### customer_dimentions.csv #############
###########################################################

# Read from OneLake
df = spark.read.format("csv")\
  .option("delimiter", ",")\
  .option("encoding", "UTF-8")\
  .option("inferSchema", "true")\
  .option("header", "true")\
  .load("Files/landing/wwi/dimension_customer.csv")
# Out:
# StatementMeta(, 14582d27-411b-4e4c-afdb-787b4ed0526f, 3, Finished, Available)

# %%
# For debugging purposes
display(df)
# Out:
# StatementMeta(, 14582d27-411b-4e4c-afdb-787b4ed0526f, 4, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 90770507-beb7-4639-9fb2-c1200a4c0ecd)

# %%
# Write file to temporary table here in LakeHouse
df.write\
    .format("delta")\
    .mode("overwrite")\
    .option("parquet.vorder.enabled ","true")\
    .saveAsTable("wwilakehouse_bronze.dimension_customer2")
# Out:
# StatementMeta(, 14582d27-411b-4e4c-afdb-787b4ed0526f, 5, Finished, Available)

# %%
# With Spark SQL, Please run the query onto the lakehouse which is from the same workspace as the current default lakehouse.

df = spark.sql("SELECT * FROM wwilakehouse_bronze.dimension_customer2 LIMIT 1000")
display(df)
